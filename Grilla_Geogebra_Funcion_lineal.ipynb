# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython import display as dp

# %%
def line(m, b):
    x = np.linspace(-10, 10, 100)
    y = m*x +b
    plt.plot(x, y)
    plt.axis("scaled")
    plt.xlim(-10, 10)
    plt.ylim(-10, 10)
    plt.show()

# %%
line(1,5)

# %% [markdown]
# ## Sliders

# %%
slider1 = widgets.IntSlider(min=0, max=5, value=1, continuous_update=False, description="Pendiente")
slider2 = widgets.FloatSlider(min=1, max=5, value=0, step=0.1, description="Corte de ordenada")

gui = widgets.interactive(line, m=slider1, b=slider2)
dp.display(gui)

# %% [markdown]
# ## Crear grilla estilo Geogebra

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1,2,3,14],'ro-') #Esto agrega los puntos 

# set your ticks manually
ax.xaxis.set_ticks([1.,2.,3.,10.])
ax.grid(True)

plt.show()

# %% [markdown]
# ### Versión 1

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import numpy as np

fig = plt.figure(1)
ax = fig.add_subplot(111)

# set up axis
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# draw curve
x = np.arange(-2.5,2.5,0.01)
line, = ax.plot(x, x**2)

#set bounds
ax.set_ybound(-1,7)

# create grid
#ax.xaxis.set_major_locator(MultipleLocator(1))
#ax.xaxis.set_minor_locator(MultipleLocator(0.2))
#ax.yaxis.set_major_locator(MultipleLocator(1))
#ax.yaxis.set_minor_locator(MultipleLocator(0.2))
#ax.xaxis.grid(True,'minor')
#ax.yaxis.grid(True,'minor')
#ax.xaxis.grid(True,'major',linewidth=2)
#ax.yaxis.grid(True,'major',linewidth=2)

#adjust grid on the 2s
#for idx,loc in enumerate(ax.xaxis.get_majorticklocs()):
    #if loc !=0 and loc % 2 == 0: ax.get_xgridlines()[idx].set_c('r')
#for idx,loc in enumerate(ax.yaxis.get_majorticklocs()):
    #if loc !=0 and loc % 2 == 0: ax.get_ygridlines()[idx].set_c('r')

## THIS IS THE EDIT
ax.xaxis.set_minor_locator(MultipleLocator(0.2))
ax.yaxis.set_minor_locator(MultipleLocator(0.2))
ax.xaxis.grid(True,'minor',linewidth=2)
ax.yaxis.grid(True,'minor',linewidth=2)

minor_grid_lines = [tick.gridline for tick in ax.xaxis.get_minor_ticks()]
for idx,loc in enumerate(ax.xaxis.get_minorticklocs()):
    if loc % 2.0 == 0: minor_grid_lines[idx].set_c('r' )
    elif loc % 1.0 == 0: minor_grid_lines[idx].set_c('g' )
    else: minor_grid_lines[idx].set_c( 'b' )

plt.show()

# %% [markdown]
# ### Versión 2 (La Buena)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import numpy as np
#from matplotlib.ticker import FormatStrFormatter

_fontsize_legend = 10
_fontsize = 15

DP = 3

fig = plt.figure(figsize=(12, 12), dpi=200, facecolor='w', edgecolor='k')
fig.canvas.draw()
ax = plt.gca()

# set up axis
ax.spines['left'].set_position('zero') # Eje izquierdo que pasa por cero (haciendo de eje y)
ax.spines['right'].set_color('green') # color del eje derecho se pone none
ax.spines['bottom'].set_position('zero') # Eje inferior que pasa por cero (haciendo de eje x)
ax.spines['top'].set_color('purple') # color del eje superior se pone none
ax.xaxis.set_ticks_position('bottom') # Marcas de graduación debajo del eje x
ax.yaxis.set_ticks_position('left') # Marcas de graduación a la izqquierda del eje y

# draw curve
x = np.arange(-10,10,0.01)
line, = ax.plot(x, x**2)

##set bounds##
#El método set_ybound() se utiliza para establecer los límites (boundaries) en el eje y del gráfico.

#En este caso, ax.set_ybound(-1, 10) establece los límites en el eje y del gráfico de Matplotlib. 
#El primer argumento (-1) representa el límite inferior del eje y, mientras que el segundo argumento (10) representa el límite superior.

#Esto significa que el eje y se mostrará en el rango de -1 a 10 en el gráfico, lo que limitará los datos visualizados a ese rango específico en el eje y. 
#Cualquier punto de datos fuera de este rango no será visible en el gráfico. 
#Este método es útil cuando se desea controlar la escala y el rango de los ejes en el gráfico.
ax.set_ybound(-1,10)

## THIS IS THE EDIT
#En Matplotlib, el localizador principal se utiliza para determinar la ubicación de las marcas principales (ticks mayores) en el eje.
#Estas marcas mayores son las marcas más visibles en el eje que generalmente se etiquetan con números o etiquetas significativas.

ax.xaxis.set_major_locator(MultipleLocator(1)) # Si se quiere hacer un zoom se puede pone 1/2, 1/4 para tener cada 2 cuadrados 1 cm

#La función MultipleLocator() se utiliza para configurar el localizador principal para que coloque las marcas mayores en intervalos regulares. 
#En este caso, se configura para que coloque las marcas mayores en el eje x en intervalos de 1/4 (0.25 unidades). 
#Esto significa que habrá una marca mayor en cada 0.25 unidades en el eje x.

ax.yaxis.set_major_locator(MultipleLocator(1))

# En el contexto de Matplotlib, ax.xaxis.grid(True, 'minor', linewidth=0.5/DP, linestyle='-', color='#d7d7d7') 
# habilita las líneas verticales de la cuadrícula en el eje x del gráfico para las marcas menores (minor ticks).
# zorder=0: Establece el orden de apilamiento de los elementos en el gráfico.
# Un valor de 0 indica que las líneas de la cuadrícula se dibujarán debajo de otros elementos del gráfico.
ax.xaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7',zorder=0)

ax.yaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7') # Lineas que atraviesan los enteros del eje y

# Este código configura el localizador secundario (minor locator) en el eje x del gráfico.
# En Matplotlib, el localizador secundario se utiliza para determinar la ubicación de las marcas secundarias (ticks menores) en el eje.
# Estas marcas menores son menos visibles que las marcas mayores y pueden ser útiles para identificar intervalos más pequeños entre las marcas mayores.
# El método set_minor_locator() se utiliza para establecer el localizador secundario en un eje específico.
# En este caso, ax.xaxis.set_minor_locator() configura el localizador secundario en el eje x del gráfico.
# La función MultipleLocator() se utiliza para configurar el localizador secundario para que coloque las marcas menores en intervalos regulares. En este caso, se configura para que coloque las marcas menores en el eje x en intervalos de 1/10 (0.1 unidades). Esto significa que habrá una marca menor en cada 0.1 unidades en el eje x.
ax.xaxis.set_minor_locator(MultipleLocator( (1) / 10 )) # 10 milimitros por cm en cuadraditos
ax.yaxis.set_minor_locator(MultipleLocator( (1) / 10 )) # igual se puede poner 5

#En el contexto de Matplotlib, ax.xaxis.grid(True, 'minor', linewidth=0.5/DP, linestyle='-', color='#d7d7d7') 
# habilita las líneas de la cuadrícula en el eje x del gráfico para las marcas menores (minor ticks).
ax.xaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7')
ax.yaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7')

# La línea de código ax.set_axisbelow(True) establece la propiedad axisbelow del objeto de ejes (ax) en True.
# Cuando axisbelow se establece en True, indica a Matplotlib que las líneas de la cuadrícula y los datos trazados
# deben dibujarse debajo de todos los demás elementos del gráfico, como las etiquetas de los ejes y las leyendas.
# Esto puede ser útil para asegurarse de que las líneas de la cuadrícula no interfieran con otros elementos del gráfico y
# que los datos trazados estén más prominentemente visibles.
ax.set_axisbelow(True)

# El método ax.set_aspect('equal') establece la relación de aspecto del sistema de coordenadas del gráfico como "igual".
# Cuando se establece la relación de aspecto en "igual", 
# Matplotlib ajustará automáticamente los ejes x e y para que tengan la misma escala en términos de unidades de longitud en los ejes. 
# Esto significa que una unidad en el eje x tendrá la misma longitud que una unidad en el eje y en términos de distancia en la gráfica.
ax.set_aspect('equal')

#ax.axhline(linewidth=0) # Engrosar el eje x agregando una linea encima
#ax.axvline(linewidth=0) # Engrosar el eje y agregando una linea encima

# Este fragmento de código configura el formateador de las etiquetas de las marcas mayores (major ticks) en el eje x del gráfico.
# En Matplotlib, el formateador de etiquetas (Formatter) se utiliza para especificar cómo se deben formatear los valores de las etiquetas
# de las marcas en los ejes del gráfico. En este caso, ax.xaxis.set_major_formatter() configura el formateador 
# de las etiquetas de las marcas mayores en el eje x del gráfico.
# El argumento FormatStrFormatter('%i') indica que se utilizará un formateador de cadena (FormatStrFormatter) y 
# que los valores de las etiquetas se formatearán como enteros (%i). Esto significa que los valores numéricos en el 
# eje x se mostrarán como números enteros, sin decimales.
ax.xaxis.set_major_formatter(FormatStrFormatter('%i'))

# En Matplotlib, los ticks son las marcas pequeñas en los ejes que indican valores específicos. 
# Los ticks mayores son las marcas principales que suelen tener etiquetas asociadas, mientras que los ticks menores son marcas secundarias entre los ticks mayores.
# La función ax.xaxis.get_major_ticks() se utiliza para obtener una lista de objetos Tick 
# que representan las marcas mayores en el eje x del gráfico. Cada objeto Tick contiene información sobre la posición y el formato de una marca mayor en el eje x.
# Al almacenar estas marcas mayores en la variable xticks, puedes acceder a ellas y manipularlas según sea necesario en tu código. 
# Por ejemplo, puedes ajustar sus propiedades o eliminarlas del gráfico si es necesario.
xticks = ax.xaxis.get_major_ticks()


# Este fragmento de código itera sobre las marcas mayores (major ticks) en el eje x del gráfico, 
# utilizando un bucle for junto con la función enumerate() para obtener tanto el índice como el objeto de cada marca. 
# Luego, verifica si el índice menos uno (resta uno para empezar desde cero) es un múltiplo de 4 utilizando el operador de módulo %. 
# Si la condición se cumple, la etiqueta correspondiente se hace visible y se ajusta el tamaño de la fuente al valor almacenado en la variable _fontsize. 
# De lo contrario, la etiqueta se hace invisible.
# Esto se hace para cada cuarta marca mayor en el eje x (a partir del segundo tick) para hacer visibles las etiquetas cada cuatro marcas y ajustar el tamaño de la fuente de esas etiquetas. 
# Las demás etiquetas se vuelven invisibles.
# Es una forma de personalizar la apariencia de las etiquetas en el eje x para mostrar solo algunas de ellas, 
# lo que puede ser útil para evitar el desorden y mejorar la legibilidad del gráfico.
# i: Representa el índice de la marca mayor actual en la lista xticks.
# l: Representa el objeto de la marca mayor actual en la lista xticks.

for i,l in enumerate(xticks):
    if not (i - 1) % 4 == 0:
        xticks[i].label1.set_visible(False) # True para que muestre cada digito
    else:
        xticks[i].label1.set_fontsize(_fontsize)

ax.yaxis.set_major_formatter(FormatStrFormatter('%i')) # Formateador entero para eje y
yticks = ax.yaxis.get_major_ticks() # Obtener la lista de ticks en eje y para poder iterar con for
for i,l in enumerate(yticks):
    if not (i - 1) % 4 == 0:
        yticks[i].label1.set_visible(False)
    else:
        yticks[i].label1.set_fontsize(_fontsize)    

# La función plt.get_current_fig_manager() en Matplotlib se utiliza para obtener el administrador de la ventana de la figura actual.
# Cuando creas una figura en Matplotlib, esta se representa visualmente en una ventana. 
# El administrador de la ventana de la figura gestiona esta ventana y proporciona métodos para controlar su tamaño, posición y otros aspectos de su apariencia.
# Al llamar a plt.get_current_fig_manager(), obtienes una referencia al administrador de la ventana de la figura actual.
# Puedes utilizar este objeto para realizar ajustes en la ventana de la figura, como cambiar su tamaño, maximizarla o minimizarla, entre otros.

#figManager = plt.get_current_fig_manager() # Puede omitirse ya que no usamos ventana

#figManager.window.showMaximized() # Ademas que no existe desde Matplotlib 3.8 no existiendo la clase window, es totalmente innecesario 
# ya que se puede maximizar mediante los controles agregando arriba el magic %matplotlib widget

# La función plt.show() se utiliza para mostrar la figura actual en la pantalla. 
# En entornos interactivos como Jupyter Notebook, esta función es necesaria para mostrar la figura después de que se hayan realizado todos los ajustes y trazados.
# Al llamar a plt.show(), se abre una ventana que muestra la figura actualizada con todos los elementos gráficos y ajustes que hayas realizado. 
# En un script de Python, plt.show() suele ser la última línea de código que se ejecuta para mostrar la figura antes de que el script termine de ejecutarse.
# En un entorno interactivo como Jupyter Notebook, plt.show() puede no ser necesario, 
# ya que las figuras se muestran automáticamente después de ejecutar una celda que contiene código de trazado. 
# Sin embargo, en algunos casos, especialmente si se están creando múltiples figuras en una celda o si se están realizando operaciones más complejas de trazado, 
# es posible que necesites llamar a plt.show() para asegurarte de que todas las figuras se muestren correctamente.

#plt.show()

# %% [markdown]
# ### Función Lineal

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import numpy as np
#from matplotlib.ticker import FormatStrFormatter

_fontsize_legend = 10
_fontsize = 15

DP = 3

fig = plt.figure(figsize=(12, 12), dpi=200, facecolor='w', edgecolor='k')
##fig = plt.figure()
fig.canvas.draw()
ax = plt.gca()

# set up axis
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('green')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_color('purple')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

#set bounds
ax.set_ybound(-1,10)

## THIS IS THE EDIT
ax.xaxis.set_major_locator(MultipleLocator(1)) # Si se quiere hacer un zoom se puede pone 1/2, 1/4 para tener cada 2 cuadrados 1 cm
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7',zorder=0) # Lineas Que atraviesan el eje x en los enteros
ax.yaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7') # Lineas que atraviesan el eje y en los enteros

ax.xaxis.set_minor_locator(MultipleLocator( (1) / 10 )) # 10 milimitros por cm en cuadraditos
ax.yaxis.set_minor_locator(MultipleLocator( (1) / 10 )) # igual se puede poner 5
ax.xaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7')
ax.yaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7')

ax.set_axisbelow(True)
ax.set_aspect('equal')

#ax.axhline(linewidth=0)
#ax.axvline(linewidth=0)

ax.xaxis.set_major_formatter(FormatStrFormatter('%i'))
xticks = ax.xaxis.get_major_ticks()
for i,l in enumerate(xticks):
    if not (i - 1) % 4 == 0:
        xticks[i].label1.set_visible(True)
    else:
        xticks[i].label1.set_fontsize(_fontsize)

ax.yaxis.set_major_formatter(FormatStrFormatter('%i'))
yticks = ax.yaxis.get_major_ticks()
for i,l in enumerate(yticks):
    if not (i - 1) % 4 == 0:
        yticks[i].label1.set_visible(True)
    else:
        yticks[i].label1.set_fontsize(_fontsize)    

# draw curve
x = np.arange(-10,10,0.01)
line, = ax.plot(x, 2*x +1)

figManager = plt.get_current_fig_manager()
#figManager.full_screen_toggle()
#figManager.window.showMaximized()
plt.show()

# %% [markdown]
# ### Probando el código por línnea

# %%
#%matplotlib widget
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import numpy as np
#from matplotlib.ticker import FormatStrFormatter

_fontsize_legend = 10
_fontsize = 15

DP = 3

fig = plt.figure(figsize=(12, 12), dpi=200, facecolor='w', edgecolor='k')
fig.canvas.draw()
ax = plt.gca()

# set up axis
ax.spines['left'].set_position('zero') # Eje izquierdo que pasa por cero (haciendo de eje y)
ax.spines['right'].set_color('none') # color del eje derecho se pone none
ax.spines['bottom'].set_position('zero') # Eje inferior que pasa por cero (haciendo de eje x)
ax.spines['top'].set_color('none') # color del eje superior se pone none
ax.xaxis.set_ticks_position('bottom') # Marcas de graduación debajo del eje x
ax.yaxis.set_ticks_position('left') # Marcas de graduación a la izqquierda del eje y

ax.set_ybound(-1,10)
ax.set_xbound(-1,10)

ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))

ax.xaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7',zorder=0)
ax.yaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7')
ax.xaxis.set_minor_locator(MultipleLocator( (1) / 10 ))
ax.yaxis.set_minor_locator(MultipleLocator( (1) / 10 ))
ax.xaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7') # Verticales cada 1 division(mm) en el eje x
ax.yaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7') # horizontales cada 1 división(mm) en el eje y

ax.set_axisbelow(True) # Mandar al fondo a las grillas
ax.set_aspect('equal') # Asegura que la distancia entre los ticks y la   grafica se mantengan iguales en ambos ejes

#ax.axhline(linewidth=2) # Pone una linea horizontal en el eje x
#ax.axvline(linewidth=2) # # Pone una linea vertical en el eje y No hace falta, a menos que se quiera engrosar los ejes

ax.xaxis.set_major_formatter(FormatStrFormatter('%i')) # Formateador entero para eje x
xticks = ax.xaxis.get_major_ticks() # Obtener la lista de ticks en eje x para poder iterar con for
for i,l in enumerate(xticks):
    if not (i - 1) % 4 == 0: # Hace que el numero pueda ser visible cada 4
        xticks[i].label1.set_visible(True) # True para que muestre cada digito
    else:
        xticks[i].label1.set_fontsize(_fontsize)

ax.yaxis.set_major_formatter(FormatStrFormatter('%i')) # Formateador entero para eje y
yticks = ax.yaxis.get_major_ticks() # Obtener la lista de ticks en eje y para poder iterar con for
for i,l in enumerate(yticks):
    if not (i - 1) % 4 == 0:
        yticks[i].label1.set_visible(True)
    else:
        yticks[i].label1.set_fontsize(_fontsize)

plt.show() #Innecesario en Jupyter Lab

# %%
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Función para actualizar el gráfico
def update_plot(x_min, x_max, y_min, y_max):
    plt.figure(figsize=(6, 4))
    plt.plot(x, y)
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    plt.xticks(range(x_min, x_max + 1))
    plt.yticks(range(y_min, y_max + 1))
    plt.grid(True)
    plt.show()

# Crear sliders para ajustar los límites de los ejes
x_min_slider = widgets.IntSlider(value=min(x), min=min(x), max=max(x), description='x min')
x_max_slider = widgets.IntSlider(value=max(x), min=min(x), max=max(x), description='x max')
y_min_slider = widgets.IntSlider(value=min(y), min=min(y), max=max(y), description='y min')
y_max_slider = widgets.IntSlider(value=max(y), min=min(y), max=max(y), description='y max')

# Llamar a la función de actualización cuando se cambian los valores de los sliders
widgets.interactive(update_plot, x_min=x_min_slider, x_max=x_max_slider, y_min=y_min_slider, y_max=y_max_slider)

# %% [markdown]
# # Plantilla
# ### Grafico estilo grilla pero en ipywidget
# Se inserta todo el código de matplotlib en una función, exceptuando las variables aunque podrian estar dentro de la función, pero es común dejarlas afuera.
#
# #### Se agregan:
#
# ``import ipywidgets as widgets``
#
# ``from IPython.display import display``
#
# #### Ademas se realizan las siguientes diferencias:
# - ``fig = plt.figure(figsize=(12, 12), dpi=200, facecolor='w', edgecolor='k')`` pasa a ``fig, ax = plt.subplots(figsize=(12, 12), dpi=200, facecolor='w', edgecolor='k')`` y se elimina ``ax = plt.gca()``
# - ``fig.canvas.draw()`` pasa a ``ax.plot(x, y)``
# - como los sliders x_max e y_max se crean como widgets se cambian los limites(bound)
# - #### Crear sliders para ajustar los límites de los ejes
#     - ``x_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='x max')``
#     - ``y_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='y max')``
# - #### Llamar a la función de actualización cuando se cambian los valores de los sliders
#     - ``widgets.interactive(update_plot, x_max=x_max_slider, y_max=y_max_slider)``

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import numpy as np
import ipywidgets as widgets
from IPython.display import display

_fontsize_legend = 10
_fontsize = 15
DP = 3

# Datos a graficar: #

def update_plot(x_max, y_max):
    #plt.clf()  # Limpiar la figura actual
    #fig = plt.figure(figsize=(12, 12), dpi=200, facecolor='w', edgecolor='k')
    fig, ax = plt.subplots(figsize=(12, 12), dpi=200, facecolor='w', edgecolor='k') #ipywidget crea figure y axes en una linea y usa subplots()
    #fig.canvas.draw() # ax.plot(x, y) es igual pero hace que se grafique en ipywidget
    ax = plt.gca() #Desactivar cuando se tengan datos y usar ax.plot(x,y)
    #ax.plot(x,y) # Con ipywidget es necesario!
    ax.spines['left'].set_position('zero') # Eje izquierdo que pasa por cero (haciendo de eje y)
    ax.spines['right'].set_color('none') # color del eje derecho se pone none
    ax.spines['bottom'].set_position('zero') # Eje inferior que pasa por cero (haciendo de eje x)
    ax.spines['top'].set_color('none') # color del eje superior se pone none
    ax.xaxis.set_ticks_position('bottom') # Marcas de graduación debajo del eje x
    ax.yaxis.set_ticks_position('left') # Marcas de graduación a la izqquierda del eje y
    
    ax.set_ybound(-1,y_max) # ax.set_xlim(-1, x_max) es igual, para aprovechar ipywidgets se cambio 10 por y_max
    ax.set_xbound(-1,x_max) # ax.set_ylim(-1, y_max) es igual
    
    ax.xaxis.set_major_locator(MultipleLocator(1)) # ax.xaxis.set_major_locator(plt.MultipleLocator(1)) con ipywidgets difiere por que no se importo MultipleLocator entonces se lo llama con plt.Multiplicator
    ax.yaxis.set_major_locator(MultipleLocator(1))
    
    ax.xaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7',zorder=0) # ax.xaxis.grid(True, 'major', linewidth=2/3, linestyle='-', color='#d7d7d7', zorder=0) es igual no usa la variable DP con ipywidget
    ax.yaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7')
    ax.xaxis.set_minor_locator(MultipleLocator( (1) / 10 ))
    ax.yaxis.set_minor_locator(MultipleLocator( (1) / 10 ))
    ax.xaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7') # Verticales cada 1 division(mm) en el eje x
    # ax.xaxis.grid(True, 'minor', linewidth=0.5/3, linestyle='-', color='#d7d7d7', zorder=0) con ipywidgets no usa DP y agrega zorder 
    ax.yaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7') # horizontales cada 1 división(mm) en el eje y
    
    ax.set_axisbelow(True) # Mandar al fondo a las grillas
    ax.set_aspect('equal') # Asegura que la distancia entre los ticks y la   grafica se mantengan iguales en ambos ejes
    # ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%i')) con ipywidgets 
    ax.xaxis.set_major_formatter(FormatStrFormatter('%i')) # Formateador entero para eje x
    xticks = ax.xaxis.get_major_ticks() # Obtener la lista de ticks en eje x para poder iterar con for
    for i,l in enumerate(xticks):
        if not (i - 1) % 4 == 0: # Hace que el numero pueda ser visible cada 4
            xticks[i].label1.set_visible(True) # True para que muestre cada digito
        else:
            xticks[i].label1.set_fontsize(_fontsize)
    
    ax.yaxis.set_major_formatter(FormatStrFormatter('%i')) # Formateador entero para eje y
    yticks = ax.yaxis.get_major_ticks() # Obtener la lista de ticks en eje y para poder iterar con for
    for i,l in enumerate(yticks):
        if not (i - 1) % 4 == 0:
            yticks[i].label1.set_visible(True)
        else:
            yticks[i].label1.set_fontsize(_fontsize)

# Crear sliders para ajustar los límites de los ejes
x_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='x max')
y_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='y max')


# Llamar a la función de actualización cuando se cambian los valores de los sliders
widgets.interactive(update_plot, x_max=x_max_slider, y_max=y_max_slider)
# Out:
# interactive(children=(IntSlider(value=10, description='x max', max=20, min=1), IntSlider(value=10, description…

# %% [markdown]
# ## Versión reducida

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import ipywidgets as widgets
from IPython.display import display

x = np.linspace(-10,10,100)
y = 1*x +1
def update_plot(x_max, y_max):
    fig, ax = plt.subplots(figsize=(12, 12), dpi=200)
    ax.plot(x, y)
    ax.set_xlim(-1, x_max)
    ax.set_ylim(-1, y_max)
    ax.spines['left'].set_position('zero')
    ax.spines['bottom'].set_position('zero')
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_major_locator(MultipleLocator(1))
    ax.yaxis.set_major_locator(MultipleLocator(1))
    ax.xaxis.grid(True, 'major', linewidth=2/3, linestyle='-', color='#d7d7d7', zorder=0)
    ax.yaxis.grid(True, 'major', linewidth=2/3, linestyle='-', color='#d7d7d7', zorder=0)
    ax.xaxis.set_minor_locator(MultipleLocator(0.1))
    ax.yaxis.set_minor_locator(MultipleLocator(0.1))
    ax.xaxis.grid(True, 'minor', linewidth=0.5/3, linestyle='-', color='#d7d7d7', zorder=0)
    ax.yaxis.grid(True, 'minor', linewidth=0.5/3, linestyle='-', color='#d7d7d7', zorder=0)
    ax.set_axisbelow(True)
    ax.set_aspect('equal')
    ax.xaxis.set_major_formatter(FormatStrFormatter('%i'))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%i'))
    plt.show()

# Crear sliders para ajustar los límites de los ejes
x_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='x max')
y_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='y max')

# Llamar a la función de actualización cuando se cambian los valores de los sliders
widgets.interactive(update_plot, x_max=x_max_slider, y_max=y_max_slider)
# Out:
# interactive(children=(IntSlider(value=10, description='x max', max=20, min=1), IntSlider(value=10, description…

# %% [markdown]
# ### Ejemplo de uso:
# - La función lineal

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import numpy as np
import ipywidgets as widgets
from IPython.display import display

_fontsize_legend = 10
_fontsize = 15
DP = 3

# Datos a graficar:
def line(m, b):
    x = np.linspace(-10, 10, 100)
    y = m*x +b
    return x, y

def update_plot(x_max, y_max,m,b): #Se agrega m,b para ser ingresados con los sliders 
    fig, ax = plt.subplots(figsize=(12, 12), dpi=200, facecolor='b', edgecolor='k')
    x,y = line(m,b) # datos
    ax.plot(x,y)
    ax.spines['left'].set_position('zero')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('zero')
    ax.spines['top'].set_color('none') # color del eje superior se pone none
    ax.xaxis.set_ticks_position('bottom') # Marcas de graduación debajo del eje x
    ax.yaxis.set_ticks_position('left') # Marcas de graduación a la izqquierda del eje y
    
    ax.set_ybound(-10,y_max) # ax.set_xlim(-1, x_max) es igual, para aprovechar ipywidgets se cambio 10 por y_max
    ax.set_xbound(-10,x_max) # ax.set_ylim(-1, y_max) es igual
    
    ax.xaxis.set_major_locator(MultipleLocator(1)) # ax.xaxis.set_major_locator(plt.MultipleLocator(1)) con ipywidgets difiere por que no se importo MultipleLocator entonces se lo llama con plt.Multiplicator
    ax.yaxis.set_major_locator(MultipleLocator(1))
    
    ax.xaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7',zorder=0) # ax.xaxis.grid(True, 'major', linewidth=2/3, linestyle='-', color='#d7d7d7', zorder=0) es igual no usa la variable DP con ipywidget
    ax.yaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7')
    ax.xaxis.set_minor_locator(MultipleLocator( (1) / 10 ))
    ax.yaxis.set_minor_locator(MultipleLocator( (1) / 10 ))
    ax.xaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7') # Verticales cada 1 division(mm) en el eje x
    # ax.xaxis.grid(True, 'minor', linewidth=0.5/3, linestyle='-', color='#d7d7d7', zorder=0) con ipywidgets no usa DP y agrega zorder 
    ax.yaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7') # horizontales cada 1 división(mm) en el eje y
    
    ax.set_axisbelow(True) # Mandar al fondo a las grillas
    ax.set_aspect('equal') # Asegura que la distancia entre los ticks y la   grafica se mantengan iguales en ambos ejes
    # ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%i')) con ipywidgets 
    ax.xaxis.set_major_formatter(FormatStrFormatter('%i')) # Formateador entero para eje x
    xticks = ax.xaxis.get_major_ticks() # Obtener la lista de ticks en eje x para poder iterar con for
    for i,l in enumerate(xticks):
        if not (i - 1) % 4 == 0: # Hace que el numero pueda ser visible cada 4
            xticks[i].label1.set_visible(True) # True para que muestre cada digito
        else:
            xticks[i].label1.set_fontsize(_fontsize)
    
    ax.yaxis.set_major_formatter(FormatStrFormatter('%i')) # Formateador entero para eje y
    yticks = ax.yaxis.get_major_ticks() # Obtener la lista de ticks en eje y para poder iterar con for
    for i,l in enumerate(yticks):
        if not (i - 1) % 4 == 0:
            yticks[i].label1.set_visible(True)
        else:
            yticks[i].label1.set_fontsize(_fontsize)

# Crear sliders para ajustar los límites de los ejes
x_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='x max')
y_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='y max')
slider_m = widgets.IntSlider(min=-5, max=5, value=1, continuous_update=True, description="Pendiente")
slider_b = widgets.FloatSlider(min=1, max=5, value=0, step=0.1, description="Corte de ordenada")


# Llamar a la función de actualización cuando se cambian los valores de los sliders
widgets.interactive(update_plot, x_max=x_max_slider, y_max=y_max_slider, m=slider_m, b=slider_b)
# Out:
# interactive(children=(IntSlider(value=10, description='x max', max=20, min=1), IntSlider(value=10, description…

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import numpy as np
import ipywidgets as widgets
from IPython.display import display

_fontsize_legend = 10
_fontsize = 15
DP = 3

# Datos a graficar:
def quadratic(a, b, c):
    x = np.linspace(-10, 10, 100)
    y = a*x**2 + b*x + c
    return x, y

def update_plot(x_max, y_max,a,b,c):
    fig, ax = plt.subplots(figsize=(12, 12), dpi=200, facecolor='r', edgecolor='k')
    x,y = quadratic(a,b,c) # datos
    ax.plot(x,y)
    ax.spines['left'].set_position('zero')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('zero')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
    ax.set_ybound(-10,y_max)
    ax.set_xbound(-10,x_max)
    
    ax.xaxis.set_major_locator(MultipleLocator(1))
    ax.yaxis.set_major_locator(MultipleLocator(1))
    
    ax.xaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7',zorder=0)
    ax.yaxis.grid(True,'major',linewidth=2/DP,linestyle='-',color='#d7d7d7')
    ax.xaxis.set_minor_locator(MultipleLocator( (1) / 10 ))
    ax.yaxis.set_minor_locator(MultipleLocator( (1) / 10 ))
    ax.xaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7')
    ax.yaxis.grid(True,'minor',linewidth=0.5/DP,linestyle='-',color='#d7d7d7')
    
    ax.set_axisbelow(True)
    ax.set_aspect('equal')
    ax.xaxis.set_major_formatter(FormatStrFormatter('%i'))
    xticks = ax.xaxis.get_major_ticks()
    for i,l in enumerate(xticks):
        if not (i - 1) % 4 == 0:
            xticks[i].label1.set_visible(True)
        else:
            xticks[i].label1.set_fontsize(_fontsize)
    
    ax.yaxis.set_major_formatter(FormatStrFormatter('%i'))
    yticks = ax.yaxis.get_major_ticks()
    for i,l in enumerate(yticks):
        if not (i - 1) % 4 == 0:
            yticks[i].label1.set_visible(True)
        else:
            yticks[i].label1.set_fontsize(_fontsize)

# Crear sliders para ajustar los límites de los ejes
x_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='x max')
y_max_slider = widgets.IntSlider(value=10, min=1, max=20, description='y max')
slider_a = widgets.IntSlider(min=-5, max=5, value=1, continuous_update=True, description="Coeficiente Principal")
slider_b = widgets.FloatSlider(min=-5, max=5, value=0, step=0.1, description="Pendiente")
slider_c = widgets.FloatSlider(min=-5, max=5, value=0, step=0.1, description="Corte de ordenada")

# Llamar a la función de actualización cuando se cambian los valores de los sliders
widgets.interactive(update_plot, x_max=x_max_slider, y_max=y_max_slider, a=slider_a, b=slider_b, c=slider_c)
# Out:
# interactive(children=(IntSlider(value=10, description='x max', max=20, min=1), IntSlider(value=10, description…
